# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("Null values in data\n",df.isnull().sum())
# Out:
# Null values in data
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print("Describtion of Dataset:\n", df.describe())
# Out:
# Describtion of Dataset:
#         PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print("Varible Datatypes:\n", df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# Varible Datatypes:
#  None

# %%
print("Shape or Dimension of dataset:\n", df.shape)
# Out:
# Shape or Dimension of dataset:
#  (891, 12)

# %%
df["Survived"] = df["Survived"].astype('category')

# %%
df["Survived"].dtypes
# Out:
# CategoricalDtype(categories=[0, 1], ordered=False, categories_dtype=int64)

# %%
df["Survived"] = df["Survived"].map({0: "Dead", 1: "Live"})

# %%
df["Sex"] = df["Sex"].map({'male':0, 'female':1})

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1     Dead       3
# 1            2     Live       1
# 2            3     Live       3
# 3            4     Live       1
# 4            5     Dead       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df= pd.get_dummies(df, columns=["Embarked"], drop_first=True)

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1     Dead       3
# 1            2     Live       1
# 2            3     Live       3
# 3            4     Live       1
# 4            5     Dead       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN       False        True
# 1          PC 17599  71.2833   C85       False       False
# 2  STON/O2. 3101282   7.9250   NaN       False        True
# 3            113803  53.1000  C123       False        True
# ...

# %%
df1 = pd.read_csv("academic_performance_dataset.csv")
df1.head()
# Out:
#    Student_ID  Math_Score  Science_Score  English_Score  \
# 0           1        78.0           80.0           75.0
# 1           2        85.0           88.0           82.0
# 2           3        92.0           90.0           85.0
# 3           4        67.0           65.0           60.0
# 4           5        88.0           85.0           78.0
#
#    Attendance_Percentage  Study_Hours
# 0                   85.0            2
# 1                   90.0            4
# 2                   92.0            5
# 3                   70.0            1
# 4                   88.0            3

# %%
df1.isnull().sum()
# Out:
# Student_ID               0
# Math_Score               1
# Science_Score            1
# English_Score            1
# Attendance_Percentage    1
# Study_Hours              0
# dtype: int64

# %%
df1["Math_Score"] = df1["Math_Score"].fillna(df1["Math_Score"].mean())

# %%
df1["Science_Score"] = df1["Science_Score"].fillna(df1["Science_Score"].mean())

# %%
df1["English_Score"] = df1["English_Score"].fillna(df1["English_Score"].mean())

# %%
df1["Attendance_Percentage"] = df1["Attendance_Percentage"].fillna(df1["Attendance_Percentage"].mean())

# %%
df1.isnull().sum()
# Out:
# Student_ID               0
# Math_Score               0
# Science_Score            0
# English_Score            0
# Attendance_Percentage    0
# Study_Hours              0
# dtype: int64

# %%
numeric = df1[["Math_Score", "Science_Score", "English_Score", "Attendance_Percentage", "Study_Hours"]]

# %%
Q1 = numeric.quantile(0.25)
Q3 = numeric.quantile(0.75)
IQR = Q3-Q1
lower = Q1-1.5*IQR
upper = Q3+1.5*IQR
IQR_outlier = ((numeric<lower)|(numeric>upper))
IQR_outlier
# Out:
#     Math_Score  Science_Score  English_Score  Attendance_Percentage  \
# 0        False          False          False                  False
# 1        False          False          False                  False
# 2        False          False          False                  False
# 3        False          False          False                  False
# 4        False          False          False                  False
# 5        False          False          False                  False
# 6        False          False          False                   True
# 7        False          False          False                  False
# 8        False          False          False                  False
# 9        False          False          False                  False
# 10       False          False          False                  False
# 11        True          False          False                   True
# 12       False          False          False                  False
# ...

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df1 )
plt.show()

# %%
df2 = df1.drop("Study_Hours", axis=1)
plt.scatter( df1.index, df1["Study_Hours"])
plt.title("Before outlier ")
plt.show()

# %%
IQR_outlier1 = ((numeric>=lower)&(numeric<=upper))
IQR_outlier1
# Out:
#     Math_Score  Science_Score  English_Score  Attendance_Percentage  \
# 0         True           True           True                   True
# 1         True           True           True                   True
# 2         True           True           True                   True
# 3         True           True           True                   True
# 4         True           True           True                   True
# 5         True           True           True                   True
# 6         True           True           True                  False
# 7         True           True           True                   True
# 8         True           True           True                   True
# 9         True           True           True                   True
# 10        True           True           True                   True
# 11       False           True           True                  False
# 12        True           True           True                   True
# ...

# %%
df_clean = numeric[IQR_outlier1.all(axis=1)]
df_clean
# Out:
#     Math_Score  Science_Score  English_Score  Attendance_Percentage  \
# 0    78.000000      80.000000      75.000000              85.000000
# 1    85.000000      88.000000      82.000000              90.000000
# 2    92.000000      90.000000      85.000000              92.000000
# 3    67.000000      65.000000      60.000000              70.000000
# 4    88.000000      85.000000      78.000000              88.000000
# 5    90.000000      92.000000      88.000000              95.000000
# 7    73.000000      70.000000      69.000000              80.000000
# 8    81.000000      79.000000      77.000000              86.000000
# 9    95.000000      96.000000      90.000000              94.000000
# 10  100.000000      98.000000      92.000000              96.000000
# 12   89.000000      87.000000      80.000000              89.000000
# 13   76.000000      74.000000      75.947368              82.000000
# 14   84.000000      84.526316      83.000000              87.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df1 = df1.drop("Student_ID", axis=1)
df1.hist(figsize=(10,8))
plt.show()

# %%
df2 = df1.drop("Study_Hours", axis=1)
plt.scatter( df_clean.index, df_clean["Study_Hours"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_clean.hist(figsize=(10,8))
plt.show()

# %%
df_clean.skew()
# Out:
# Math_Score              -0.468159
# Science_Score           -0.251053
# English_Score           -0.365019
# Attendance_Percentage   -0.809445
# Study_Hours              0.460387
# dtype: float64

# %%
df_clean['Study_Hours'] = np.sqrt(df_clean['Study_Hours'])
# Out:
# C:\Users\Kadamdari\AppData\Local\Temp\ipykernel_20596\3087308179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Study_Hours'] = np.sqrt(df_clean['Study_Hours'])

# %%
df_clean.skew()
# Out:
# Math_Score              -0.468159
# Science_Score           -0.251053
# English_Score           -0.365019
# Attendance_Percentage   -0.809445
# Study_Hours             -0.121181
# dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df_clean, )
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_clean.hist(figsize=(10,8))
plt.show()
